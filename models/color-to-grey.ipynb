# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline
import skimage
import IPython.display
import PIL
from skimage import color
from skimage import io
from PIL import Image

# %%
img = Image.open('luffy.jfif')
#img2 = color.rgb2gray(io.imread('luffy.jfif'))

# %%
img = img.resize((224,224))

# %%
#IPython.display.display(PIL.Image.fromarray(new_img).convert('RGB'))

# %%
def image_converter(img):
    img1 = skimage.color.rgb2gray(img) * 255
    return img1

# %%
img1 = image_converter(img)

# %%
IPython.display.display(PIL.Image.fromarray(img1).convert('RGB'))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
